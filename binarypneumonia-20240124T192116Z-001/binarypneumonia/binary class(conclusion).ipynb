# %% [markdown]
# In this I am adding data set "PneumoniaMNIST"
# with the nessearcy changes in loss function (we will add 'binary_crossentropy' ) and we will use sigmoid activation code
# ## 1.2PneumoniaMNISTbb
# In This we will see the graphs intersecting in both accuracy vs epoch and loss vs epoch
# but atlast accuracy is showing above train data
#
# In  loss it is showing below train data
#
#
# we are also getting accuracy score of 1.0 and loose 0f 0.0
#
# ## 2.2PneumoniaMNISTbb
# In this we will and only dense layers in the model architecture which will give a accuracy of straight line above train data
#
# the loss is a curve below the training data
#
# it is giving accuracy of 1.0 and loss of 0.650
#
# ## 3.2PneumoniaMNISTbb
# In this I am using my own architecture with 2 convalutional layer and with 2 dense layers
#
# which is giving a graph with accuracy which got down at one point and suddenly increased and at last it is above training data
#
# In loose it is below the training data
#
# It is giving accuracy of 1.0 and loose of 0.04
#
# by seeing graphs of bove 3 models i can say 3rd model is good compare to first and second model because of its increasing accuracy and decreasing loose and with the accuracy value 0f 1.0 and loose of 0.04
